# %% [markdown]
# <a href="https://colab.research.google.com/github/Joelalvazer/programaci-n-orientada-a-objetos/blob/main/UNIDAD%201%20POO/codigolibro3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#sUBCLASE ESTUDIANTE
class Estudiante(Persona):
  def_init_(self, num_comtrol, nombre, carrera, fecha_nacimiento , telefono, correo):
    super(),_init_(nombre, correo, fecha_nacimiento)
    self.num_control = num_control
    self.carrera = carrera
    self.telefono = telefono

  def mostrar_infa(self):
    return (f"[Estudiate] (super().mostrat_info()), "
            f"num_control: {self.num_control}, "
            f"carrera: {self.carrera}, "
            f"telefono: {self.telefono}")


#subclase trabajador
class trabajador(Persona):
  def_init_(self, num_trbajador, nombre. correo, fecha_nacimiento, departamento, ususario, contraseña)
  super(),_init_(nombre, correo, fecha_nacimiento) #Hereda atributos a persona
  self.num_trabajador = num:trabajador
  self.departamento = depastamento
  self.usuario = usuario
  self.contraseña = contraseña

def mostrar_info(self):
  return (f"[Trabajador] (super().mostrat_info()), "
  f"num_trabajador: {self.num_trabajador}, "
  f"departamento: {self.departamento}, "
  f"usuario: {self.usuario}, "
  f"contraseña: {self.contraseña}
